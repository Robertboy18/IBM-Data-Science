# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studi

# %% [markdown]
# **Robert Joseph**
# **Scientist**

# %% [markdown]
# *I am interested in data science because I love telling stories with data and using data to help bring that data to life.*

# %% [markdown]
# ### The next cell will print the sum of 4 +3

# %%
print(4+3)
# Out:
# 7
